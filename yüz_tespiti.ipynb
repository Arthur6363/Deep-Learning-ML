# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthur6363/Deep-Learning-ML/blob/main/y%C3%BCz_tespiti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
resim = cv2.imread("/content/siyah_beyaz_resim.jpg")

# %%
plt.figure(figsize=(3,3))
plt.imshow(resim)
plt.show()

# %%
yuz_cascade = cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")

# %%
goz_cascade = cv2.CascadeClassifier("/content/haarcascade_eye.xml")

# %%
yuzler = yuz_cascade.detectMultiScale(resim, scaleFactor=1.075, minNeighbors=5, minSize=(15,15))

# %%
for (x,y,w,h) in yuzler:
  cv2.rectangle(resim, (x,y), (x+w, y+h), (255,0,0),2)
  roi = resim[y:y+h, x:x+w]
  gozler = goz_cascade.detectMultiScale(roi)
  for(ex,ey,ew,eh) in gozler:
    cv2.rectangle(roi, (ex,ey), (ex+ew, ey+eh), (0,255,0),1)
print("Yüz bulundu! Bulunan yüz sayısı=", format(len(yuzler)))
# Out:
# Yüz bulundu! Bulunan yüz sayısı= 1

# %%
plt.figure(figsize=(5,5))
plt.imshow(resim)
plt.show()
